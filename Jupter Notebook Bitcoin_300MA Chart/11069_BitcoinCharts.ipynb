# %%
import pandas as pd

# %%
btc = pd.read_csv('Coinbase_BTCUSD_cleaned_300MA.csv')
btc['Date'] = pd.to_datetime(btc["Date"])
btc.set_index("Date", inplace=True)
btc.tail()
# Out:
#                 High       300 MA
# Date
# 2019-08-17  10475.82  6450.648367
# 2019-08-18  10513.45  6463.722133
# 2019-08-19  10938.76  6478.436133
# 2019-08-20  10953.00  6494.162133
# 2019-08-21  10800.00  6509.455467

# %%
import matplotlib.pyplot as plt<?xml version="1.0" encoding="utf-8" standalone="no"?>
<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
<!-- Created with matplotlib (https://matplotlib.org/) -->
<svg height="396pt" version="1.1" viewBox="0 0 576 396" width="576pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
 <defs>
  <style type="text/css">
*{stroke-linecap:butt;stroke-linejoin:round;}
  </style>
 </defs>
 <g id="figure_1">
  <g id="patch_1">
   <path d="M 0 396 
L 576 396 
L 576 0 
L 0 0 
z
" style="fill:#ffffff;"/>
  </g>
 </g>
</svg>

# %matplotlib inline

# %%
btc.plot(figsize=(10,5));
plt.savefig('btc_ma.png')
plt.savefig('btc_ma.svg')
